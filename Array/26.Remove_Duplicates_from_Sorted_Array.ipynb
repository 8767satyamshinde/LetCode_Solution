# %% [markdown]
# ---
# 26. Remove Duplicates from Sorted Array
# Easy
# Topics
# premium lock icon
# Companies
# Hint
# Given an integer array nums sorted in non-decreasing order, remove the duplicates in-place such that each unique element appears only once. The relative order of the elements should be kept the same.
#
# Consider the number of unique elements in nums to be k​​​​​​​​​​​​​​. After removing duplicates, return the number of unique elements k.
#
# The first k elements of nums should contain the unique numbers in sorted order. The remaining elements beyond index k - 1 can be ignored.
#
# Custom Judge:
#
# The judge will test your solution with the following code:
#
# int[] nums = [...]; // Input array
# int[] expectedNums = [...]; // The expected answer with correct length
#
# int k = removeDuplicates(nums); // Calls your implementation
#
# assert k == expectedNums.length;
# for (int i = 0; i < k; i++) {
#     assert nums[i] == expectedNums[i];
# }
# If all assertions pass, then your solution will be accepted.
#
#
#
# Example 1:
#
# Input: nums = [1,1,2]
# Output: 2, nums = [1,2,_]
# Explanation: Your function should return k = 2, with the first two elements of nums being 1 and 2 respectively.
# It does not matter what you leave beyond the returned k (hence they are underscores).
# Example 2:
#
# Input: nums = [0,0,1,1,1,2,2,3,3,4]
# Output: 5, nums = [0,1,2,3,4,_,_,_,_,_]
# Explanation: Your function should return k = 5, with the first five elements of nums being 0, 1, 2, 3, and 4 respectively.
# It does not matter what you leave beyond the returned k (hence they are underscores).
#
#
# Constraints:
#
# 1 <= nums.length <= 3 * 104
# -100 <= nums[i] <= 100
# nums is sorted in non-decreasing order.
#
#
# ----

# %%
class Solution:
    def removeDuplicates(self, nums):
        if not nums:
            return 0

        i = 0  # pointer to place next unique element

        for j in range(1, len(nums)):
            if nums[j] != nums[i]:
                i += 1
                nums[i] = nums[j]

        return i + 1  # count of unique elements


# 🔍 Test Execution
if __name__ == "__main__":
    sol = Solution()

    nums1 = [1,1,2]
    k1 = sol.removeDuplicates(nums1)
    print(k1, nums1)  # Expected: 2, [1,2,_]

    nums2 = [0,0,1,1,1,2,2,3,3,4]
    k2 = sol.removeDuplicates(nums2)
    print(k2, nums2)  # Expected: 5, [0,1,2,3,4,_,_,_,_,_]
# Out:
# 2 [1, 2, 2]
# 5 [0, 1, 2, 3, 4, 2, 2, 3, 3, 4]

# %% [markdown]
# **Problem:** Remove duplicates from a sorted array — *in-place*
# **Method:** Two-pointer strategy
# **Energy:** Traditional fundamentals + Gen-Z precision 😎
#
# ---
#
# # 🧩 Code + Detailed Explanation (Every Line)
#
# ```python
# class Solution:
#     def removeDuplicates(self, nums):
#         if not nums:
#             return 0
# ```
#
# ✔ Check if array is empty
# ✔ If yes → 0 length, nothing to do
# Traditional sanity check before execution 🧠
#
# ---
#
# ```python
#         i = 0  # pointer to place next unique element
# ```
#
# ✔ `i` is the **unique element pointer**
# ✔ It starts at index `0` because first element is always unique
#
# ---
#
# ```python
#         for j in range(1, len(nums)):
# ```
#
# ✔ `j` is the **scanning pointer**
# ✔ It moves from index `1` to end
# ✔ `j` explores → `i` organizes
#
# ---
#
# ```python
#             if nums[j] != nums[i]:
# ```
#
# ✔ Check: Is current number new/unique compared to last unique?
# ✔ Since array is **sorted**, duplicates come together
#
# ---
#
# ```python
#                 i += 1
#                 nums[i] = nums[j]
# ```
#
# ✔ When a new unique value found:
# → move `i` ahead
# → copy that new unique element to position `i`
# → array updates **in-place** ✨
#
# ---
#
# ```python
#         return i + 1
# ```
#
# ✔ `i` is zero-based index
# ✔ Count of unique elements = `i + 1`
# ✔ This is `k` in problem statement
#
# ---
#
# # 🔥 FULL DRY RUN (Example)
#
# Input:
#
# ```
# nums = [0,0,1,1,1,2,2,3,3,4]
# ```
#
# | Step  | j | nums[j] | nums[i]   | Compare | Action         | New i | Array Result          |
# | ----- | - | ------- | --------- | ------- | -------------- | ----- | --------------------- |
# | Start | - | -       | nums[0]=0 | -       | Init           | i=0   | [0,0,1,1,1,2,2,3,3,4] |
# | 1     | 1 | 0       | 0         | same    | ignore         | 0     | unchanged             |
# | 2     | 2 | 1       | 0         | diff    | i=1, nums[1]=1 | 1     | [0,1,1,1,1,2,2,3,3,4] |
# | 3     | 3 | 1       | 1         | same    | ignore         | 1     | unchanged             |
# | 4     | 4 | 1       | 1         | same    | ignore         | 1     | unchanged             |
# | 5     | 5 | 2       | 1         | diff    | i=2, nums[2]=2 | 2     | [0,1,2,1,1,2,2,3,3,4] |
# | 6     | 6 | 2       | 2         | same    | ignore         | 2     | unchanged             |
# | 7     | 7 | 3       | 2         | diff    | i=3, nums[3]=3 | 3     | [0,1,2,3,1,2,2,3,3,4] |
# | 8     | 8 | 3       | 3         | same    | ignore         | 3     | unchanged             |
# | 9     | 9 | 4       | 3         | diff    | i=4, nums[4]=4 | 4     | [0,1,2,3,4,2,2,3,3,4] |
#
# ---
#
# ### 🎯 Final Result
#
# ✔ `i = 4`
# ✔ Unique count (k) = `i + 1 = 5`
# ✔ Valid portion of nums:
#
# ```
# [0,1,2,3,4]
# ```
#
# ✔ Rest can be ignored:
#
# ```
# [_,_,_,_,_]
# ```
#
# **Output**
#
# ```
# k = 5, nums = [0,1,2,3,4,_,_,_,_,_]
# ```
#
# ---
#
# # 🧠 Core Concept (Interview Answer)
#
# > “We use a two-pointer technique where `j` scans for new unique values
# > and `i` marks the last position of unique values.
# > When a new unique number is found, we update the array in-place
# > and return `i + 1` as the count.”
#
# ---
