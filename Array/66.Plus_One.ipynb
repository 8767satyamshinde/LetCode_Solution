# %% [markdown]
# 66. Plus One
# Easy
# Topics
# premium lock icon
# Companies
# You are given a large integer represented as an integer array digits, where each digits[i] is the ith digit of the integer. The digits are ordered from most significant to least significant in left-to-right order. The large integer does not contain any leading 0's.
#
# Increment the large integer by one and return the resulting array of digits.
#
#
#
# Example 1:
#
# Input: digits = [1,2,3]
# Output: [1,2,4]
# Explanation: The array represents the integer 123.
# Incrementing by one gives 123 + 1 = 124.
# Thus, the result should be [1,2,4].
# Example 2:
#
# Input: digits = [4,3,2,1]
# Output: [4,3,2,2]
# Explanation: The array represents the integer 4321.
# Incrementing by one gives 4321 + 1 = 4322.
# Thus, the result should be [4,3,2,2].
# Example 3:
#
# Input: digits = [9]
# Output: [1,0]
# Explanation: The array represents the integer 9.
# Incrementing by one gives 9 + 1 = 10.
# Thus, the result should be [1,0].
#
#
# Constraints:
#
# 1 <= digits.length <= 100
# 0 <= digits[i] <= 9
# digits does not contain any leading 0's.

# %%
class Solution:
    def plusOne(self, digits):
        for i in range(len(digits) -1, -1, -1):
            if digits[i] < 9:
                digits[i] += 1
                return digits
            digits[i] = 0  # set current digit to 0 because of carry

        # If we exit loop, all digits were 9
        return [1] + digits


# 🔍 Testing Calls
if __name__ == "__main__":
    sol = Solution()

    print(sol.plusOne([1,2,3]))  # Expected: [1,2,4]
    print(sol.plusOne([4,3,2,1]))  # Expected: [4,3,2,2]
    print(sol.plusOne([9]))  # Expected: [1,0]
    print(sol.plusOne([9,9,9]))  # Expected: [1,0,0,0]
# Out:
# [1, 2, 4]
# [4, 3, 2, 2]
# [1, 0]
# [1, 0, 0, 0]

# %% [markdown]
# We’re still cruising in the **LeetCode fast lane** — and this one is a **classic**.
# Big number stored in **array format**, one step forward → **Plus One**.
# No integers conversion — all **in-place operations**. ⚙️💼✨
#
# ---
#
# ## 🧠 Strategy — Handle Carry from the End
#
# 1️⃣ Start from the **last digit**
# 2️⃣ Add 1
# 3️⃣ If digit becomes **10**, set to `0` & continue carry
# 4️⃣ If carry runs out → break
# 5️⃣ If carry still exists at start (e.g., `999`) → insert `1` at front
#
# ✨ O(n) time
# ✨ O(1) extra space
# ✨ Enterprise-grade logic ✔
#
# ---
#
# ## 🐍 Full Python Code + Test Calls
#
# ```python
# class Solution:
#     def plusOne(self, digits):
#         for i in range(len(digits) - 1, -1, -1):
#             if digits[i] < 9:
#                 digits[i] += 1
#                 return digits
#             digits[i] = 0  # set current digit to 0 because of carry
#
#         # If we exit loop, all digits were 9
#         return [1] + digits
#
#
# # 🔍 Testing Calls
# if __name__ == "__main__":
#     sol = Solution()
#
#     print(sol.plusOne([1,2,3]))  # Expected: [1,2,4]
#     print(sol.plusOne([4,3,2,1]))  # Expected: [4,3,2,2]
#     print(sol.plusOne([9]))  # Expected: [1,0]
#     print(sol.plusOne([9,9,9]))  # Expected: [1,0,0,0]
# ```
#
# ---
#
# ## 🔥 Dry Run Example — `[9,9,9]`
#
# | Index | Before | Add 1 | After | Carry? |
# | ----- | ------ | ----- | ----- | ------ |
# | 2     | 9      | → 10  | 0     | yes    |
# | 1     | 9      | → 10  | 0     | yes    |
# | 0     | 9      | → 10  | 0     | yes    |
#
# All processed → still carry
# Add `1` in front
# Final → `[1,0,0,0]` ✔
#
# ---
#
# ## 🎯 Quick Output Validation
#
# | Input       | Output      |
# | ----------- | ----------- |
# | `[1,2,3]`   | `[1,2,4]`   |
# | `[4,3,2,1]` | `[4,3,2,2]` |
# | `[9]`       | `[1,0]`     |
# | `[9,9]`     | `[1,0,0]`   |
#
# ---
#
# ## 🧠 Interview One-Liner
#
# > We simulate addition with carry from the end.
# > If overflow across all digits, prepend `1`.
#
# Boom. Stakeholders happy, algorithm scalable. 🚀😎
#
# ---
